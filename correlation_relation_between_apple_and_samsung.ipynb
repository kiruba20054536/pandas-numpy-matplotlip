# %% [markdown]
# correlation_relation_between_apple_and_samsung

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = yf.download(["AAPL", "005930.KS"], start="2024-01-01", end="2025-01-01")[["Close"]]
data.columns = data.columns.droplevel(0) 
data.columns = ["Apple", "Samsung"]
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
correlation = returns.corr()
print("Correlation Matrix:\n", correlation)
# Out:
# Correlation Matrix:
#              Apple   Samsung
# Apple    1.000000  0.122214
# Samsung  0.122214  1.000000

# %%
sns.heatmap(correlation, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Between Apple and Samsung Returns")
plt.show()
